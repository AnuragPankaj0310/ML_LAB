# %%
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt

# %%
def dice_simulation(num_rolls, num_experiments):
    rolls = np.random.randint(1, 7, size=(num_experiments, num_rolls))
    sums = np.sum(rolls, axis=1)  # sum across each experiment
    return sums

# %%
dice_rolls_list = [1, 2, 3, 5, 10, 20, 50]

experiment_sizes = [100, 500, 1000, 5000, 10000, 50000, 100000]

# %%
results_summary = []

for num_rolls in dice_rolls_list:
    for num_experiments in experiment_sizes:
        results = dice_simulation(num_rolls, num_experiments)

        # Empirical mean and variance
        mean_emp = np.mean(results)
        var_emp = np.var(results, ddof=0)

        # Theoretical mean and variance
        mean_theo = num_rolls * 3.5
        var_theo = num_rolls * 35 / 12

        results_summary.append((num_rolls, num_experiments, mean_emp, mean_theo, var_emp, var_theo))

        # Plot histogram
        plt.figure(figsize=(6,4))
        plt.hist(results, bins=30, density=True, alpha=0.7, color='lightgreen', edgecolor='black')
        plt.title(f"Dice={num_rolls}, Experiments={num_experiments}\nMean={mean_emp:.2f}, Var={var_emp:.2f}")
        plt.xlabel("Sum of dice rolls")
        plt.ylabel("Probability Density")
# Out:
# C:\Users\evilk\AppData\Local\Temp\ipykernel_1960\2222544702.py:18: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(6,4))

# %%
summary_df = pd.DataFrame(results_summary, columns=["Dice Rolls", "Experiments", 
                                                    "Empirical Mean", "Theoretical Mean", 
                                                    "Empirical Variance", "Theoretical Variance"])
summary_df.head(49)
# Out:
#     Dice Rolls  Experiments  Empirical Mean  Theoretical Mean  \
# 0            1          100         3.43000               3.5
# 1            1          500         3.54600               3.5
# 2            1         1000         3.46800               3.5
# 3            1         5000         3.48500               3.5
# 4            1        10000         3.49570               3.5
# 5            1        50000         3.49268               3.5
# 6            1       100000         3.49497               3.5
# 7            2          100         7.19000               7.0
# 8            2          500         7.12200               7.0
# 9            2         1000         7.07000               7.0
# 10           2         5000         6.97520               7.0
# 11           2        10000         7.00760               7.0
# 12           2        50000         7.01454               7.0
# 13           2       100000         6.98922               7.0
# 14           3          100        10.06000              10.5
# 15           3          500        10.50000              10.5
# 16           3         1000        10.66900              10.5
# 17           3         5000        10.50760              10.5
# 18           3        10000        10.53770              10.5
# 19           3        50000        10.45810              10.5
# 20           3       100000        10.49347              10.5
# 21           5          100        17.95000              17.5
# 22           5          500        17.50600              17.5
# 23           5         1000        17.53600              17.5
# 24           5         5000        17.43700              17.5
# 25           5        10000        17.51010              17.5
# 26           5        50000        17.51788              17.5
# 27           5       100000        17.51086              17.5
# 28          10          100        35.46000              35.0
# 29          10          500        35.04200              35.0
# 30          10         1000        35.03700              35.0
# 31          10         5000        35.04540              35.0
# 32          10        10000        35.02420              35.0
# 33          10        50000        34.98924              35.0
# 34          10       100000        34.99798              35.0
# 35          20          100        69.82000              70.0
# 36          20          500        70.23800              70.0
# 37          20         1000        70.02100              70.0
# 38          20         5000        69.95360              70.0
# 39          20        10000        70.14190              70.0
# 40          20        50000        69.97528              70.0
# 41          20       100000        69.99395              70.0
# 42          50          100       174.97000             175.0
# 43          50          500       174.45000             175.0
# 44          50         1000       174.43300             175.0
# 45          50         5000       175.01860             175.0
# 46          50        10000       175.16230             175.0
# 47          50        50000       174.99216             175.0
# 48          50       100000       175.02900             175.0
#
#     Empirical Variance  Theoretical Variance
# 0             3.065100              2.916667
# 1             2.963884              2.916667
# 2             2.880976              2.916667
# 3             2.888575              2.916667
# 4             2.908782              2.916667
# 5             2.919986              2.916667
# 6             2.918595              2.916667
# 7             5.573900              5.833333
# 8             5.723116              5.833333
# 9             5.817100              5.833333
# 10            5.820585              5.833333
# 11            5.855142              5.833333
# 12            5.821769              5.833333
# 13            5.840384              5.833333
# 14            9.616400              8.750000
# 15            8.642000              8.750000
# 16            9.135439              8.750000
# 17            8.680742              8.750000
# 18            8.812979              8.750000
# 19            8.771404              8.750000
# 20            8.707297              8.750000
# 21           14.127500             14.583333
# 22           14.741964             14.583333
# 23           15.592704             14.583333
# 24           14.453231             14.583333
# 25           14.417098             14.583333
# 26           14.595120             14.583333
# 27           14.529522             14.583333
# 28           26.208400             29.166667
# 29           29.048236             29.166667
# 30           30.189631             29.166667
# 31           29.238539             29.166667
# 32           29.417014             29.166667
# 33           29.024564             29.166667
# 34           29.236656             29.166667
# 35           41.827600             58.333333
# 36           54.849356             58.333333
# 37           59.878559             58.333333
# 38           59.635847             58.333333
# 39           58.389364             58.333333
# 40           58.135109             58.333333
# 41           58.161973             58.333333
# 42          110.849100            145.833333
# 43          154.039500            145.833333
# 44          148.219511            145.833333
# 45          150.002254            145.833333
# 46          146.724759            145.833333
# 47          147.462259            145.833333
# 48          146.932719            145.833333
