# %%
import pandas as pd

# Raw dataset from playCricket.pdf
play_data = [
    ["Sunny","Hot","High","Weak","No"],
    ["Sunny","Hot","High","Strong","No"],
    ["Overcast","Hot","High","Weak","Yes"],
    ["Rain","Mild","High","Weak","Yes"],
    ["Rain","Cool","Normal","Weak","Yes"],
    ["Rain","Cool","Normal","Strong","No"],
    ["Overcast","Cool","Normal","Strong","Yes"],
    ["Sunny","Mild","High","Weak","No"],
    ["Sunny","Cool","Normal","Weak","Yes"],
    ["Rain","Mild","Normal","Weak","Yes"],
    ["Sunny","Mild","Normal","Strong","Yes"],
    ["Overcast","Mild","High","Strong","Yes"],
    ["Overcast","Hot","Normal","Weak","Yes"],
    ["Rain","Mild","High","Strong","No"]
]

df_play = pd.DataFrame(play_data, columns=["Outlook","Temperature","Humidity","Wind","Play"])
df_play.head()
# Out:
#     Outlook Temperature Humidity    Wind Play
# 0     Sunny         Hot     High    Weak   No
# 1     Sunny         Hot     High  Strong   No
# 2  Overcast         Hot     High    Weak  Yes
# 3      Rain        Mild     High    Weak  Yes
# 4      Rain        Cool   Normal    Weak  Yes

# %%
from collections import Counter
from math import log2

def entropy(y):
    total = len(y)
    counts = Counter(y)
    ent = 0
    for c in counts.values():
        p = c/total
        ent -= p*log2(p)
    return ent

print("Entropy of target Play =", round(entropy(df_play["Play"]),3))
# Out:
# Entropy of target Play = 0.94

# %%
def info_gain(X, y, feature, verbose=True):
    base = entropy(y)
    n = len(y)
    weighted = 0
    if verbose:
        print(f"\nFeature: {feature}, Parent entropy = {base:.3f}")
    for v in X[feature].unique():
        sub = y[X[feature]==v]
        e = entropy(sub)
        weighted += (len(sub)/n) * e
        if verbose:
            print(f"  {feature}={v} | size={len(sub)}, entropy={e:.3f}")
    ig = base - weighted
    if verbose: print(f"  IG = {ig:.3f}")
    return ig

def split_info(X, feature):
    n = len(X)
    si = 0
    for v in X[feature].unique():
        p = len(X[X[feature]==v])/n
        if p>0: si -= p*log2(p)
    return si

def gain_ratio(X, y, feature, verbose=True):
    ig = info_gain(X,y,feature,verbose)
    si = split_info(X,feature)
    gr = ig/si if si>0 else 0
    if verbose: print(f"  SplitInfo = {si:.3f}, GainRatio = {gr:.3f}")
    return gr

# %%
def most_common(y):
    return Counter(y).most_common(1)[0][0]

def build_tree(X,y,algo="ID3",depth=0):
    if len(set(y))==1:
        return {"leaf":True,"label":y.iloc[0]}
    if X.shape[1]==0:
        return {"leaf":True,"label":most_common(y)}

    print("\n" + "="*50)
    print(f"Depth {depth} | Algorithm = {algo}")

    best_feat, best_score = None, -1
    for f in X.columns:
        score = info_gain(X,y,f,True) if algo=="ID3" else gain_ratio(X,y,f,True)
        if score > best_score:
            best_feat, best_score = f, score
    print(f">>> Best feature = {best_feat}, score = {best_score:.3f}")

    node = {"leaf":False,"feature":best_feat,"children":{}}
    for v in X[best_feat].unique():
        mask = (X[best_feat]==v)
        if mask.sum()==0:
            node["children"][v] = {"leaf":True,"label":most_common(y)}
        else:
            child = build_tree(X[mask].drop(columns=[best_feat]), y[mask], algo, depth+1)
            node["children"][v] = child
    return node

# %%
def predict_one(tree,row):
    if tree["leaf"]:
        return tree["label"]
    f = tree["feature"]
    v = row[f]
    if v in tree["children"]:
        return predict_one(tree["children"][v], row)
    else:
        return most_common([c["label"] for c in tree["children"].values() if c["leaf"]])

def predict(tree,X):
    return [predict_one(tree,row) for _,row in X.iterrows()]

# %%
import numpy as np

def accuracy(y_true,y_pred):
    return np.mean(np.array(y_true)==np.array(y_pred))

def precision_recall_f1(y_true,y_pred):
    labels = sorted(set(y_true))
    per_class = {}
    micro_tp = micro_fp = micro_fn = 0
    for l in labels:
        tp = sum((y_true==l)&(y_pred==l))
        fp = sum((y_true!=l)&(y_pred==l))
        fn = sum((y_true==l)&(y_pred!=l))
        p = tp/(tp+fp) if tp+fp>0 else 0
        r = tp/(tp+fn) if tp+fn>0 else 0
        f = (2*p*r)/(p+r) if p+r>0 else 0
        per_class[l] = (p,r,f)
        micro_tp += tp; micro_fp += fp; micro_fn += fn

    macro_f = np.mean([v[2] for v in per_class.values()])
    micro_p = micro_tp/(micro_tp+micro_fp) if micro_tp+micro_fp>0 else 0
    micro_r = micro_tp/(micro_tp+micro_fn) if micro_tp+micro_fn>0 else 0
    micro_f = (2*micro_p*micro_r)/(micro_p+micro_r) if micro_p+micro_r>0 else 0

    return per_class, macro_f, micro_f

# %%
def manual_kfold(df,k=5,target="Play",algo="ID3"):
    X = df.drop(columns=[target])
    y = df[target].reset_index(drop=True)
    n = len(df)
    idx = np.arange(n)
    np.random.seed(0)
    np.random.shuffle(idx)

    fold_size = n//k
    accs, macros, micros = [], [], []
    for i in range(k):
        start, end = i*fold_size, (i+1)*fold_size
        test_idx = idx[start:end]
        train_idx = np.setdiff1d(idx,test_idx)

        Xtr, ytr = X.iloc[train_idx], y.iloc[train_idx]
        Xte, yte = X.iloc[test_idx], y.iloc[test_idx]

        tree = build_tree(Xtr,ytr,algo)
        ypred = np.array(predict(tree,Xte))

        acc = accuracy(yte.values,ypred)
        _, macro, micro = precision_recall_f1(yte.values,ypred)

        accs.append(acc); macros.append(macro); micros.append(micro)
        print(f"Fold {i+1} | Acc={acc:.2f}, Macro-F1={macro:.2f}, Micro-F1={micro:.2f}")

    print("\n=== Final Results (",algo,") ===")
    print("Avg Acc =", np.mean(accs))
    print("Avg Macro-F1 =", np.mean(macros))
    print("Avg Micro-F1 =", np.mean(micros))

print("\nID3 Evaluation:")
manual_kfold(df_play,5,"Play","ID3")

print("\nC4.5 Evaluation:")
manual_kfold(df_play,5,"Play","C4.5")
# Out:
# ID3 Evaluation:
#
# ==================================================
# Depth 0 | Algorithm = ID3
#
# Feature: Outlook, Parent entropy = 0.980
#   Outlook=Sunny | size=4, entropy=0.811
#   Outlook=Overcast | size=3, entropy=0.000
#   Outlook=Rain | size=5, entropy=0.971
#   IG = 0.305
#
# Feature: Temperature, Parent entropy = 0.980
#   Temperature=Hot | size=4, entropy=1.000
#   Temperature=Mild | size=6, entropy=0.918
#   Temperature=Cool | size=2, entropy=1.000
#   IG = 0.021
#
# Feature: Humidity, Parent entropy = 0.980
#   Humidity=High | size=7, entropy=0.985
#   Humidity=Normal | size=5, entropy=0.722
#   IG = 0.104
#
# Feature: Wind, Parent entropy = 0.980
#   Wind=Weak | size=7, entropy=0.863
#   Wind=Strong | size=5, entropy=0.971
#   IG = 0.072
# >>> Best feature = Outlook, score = 0.305
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Temperature, Parent entropy = 0.811
#   Temperature=Hot | size=2, entropy=0.000
#   Temperature=Mild | size=2, entropy=1.000
#   IG = 0.311
#
# Feature: Humidity, Parent entropy = 0.811
#   Humidity=High | size=3, entropy=0.000
#   Humidity=Normal | size=1, entropy=0.000
#   IG = 0.811
#
# Feature: Wind, Parent entropy = 0.811
#   Wind=Weak | size=2, entropy=0.000
#   Wind=Strong | size=2, entropy=1.000
#   IG = 0.311
# >>> Best feature = Humidity, score = 0.811
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Temperature, Parent entropy = 0.971
#   Temperature=Mild | size=3, entropy=0.918
#   Temperature=Cool | size=2, entropy=1.000
#   IG = 0.020
#
# Feature: Humidity, Parent entropy = 0.971
#   Humidity=High | size=2, entropy=1.000
#   Humidity=Normal | size=3, entropy=0.918
#   IG = 0.020
#
# Feature: Wind, Parent entropy = 0.971
#   Wind=Weak | size=3, entropy=0.000
#   Wind=Strong | size=2, entropy=0.000
#   IG = 0.971
# >>> Best feature = Wind, score = 0.971
# Fold 1 | Acc=1.00, Macro-F1=1.00, Micro-F1=1.00
#
# ==================================================
# Depth 0 | Algorithm = ID3
#
# Feature: Outlook, Parent entropy = 0.980
#   Outlook=Sunny | size=5, entropy=0.971
#   Outlook=Overcast | size=3, entropy=0.000
#   Outlook=Rain | size=4, entropy=1.000
#   IG = 0.242
#
# Feature: Temperature, Parent entropy = 0.980
#   Temperature=Hot | size=4, entropy=1.000
#   Temperature=Mild | size=5, entropy=0.971
#   Temperature=Cool | size=3, entropy=0.918
#   IG = 0.012
#
# Feature: Humidity, Parent entropy = 0.980
#   Humidity=High | size=6, entropy=0.918
#   Humidity=Normal | size=6, entropy=0.650
#   IG = 0.196
#
# Feature: Wind, Parent entropy = 0.980
#   Wind=Weak | size=7, entropy=0.863
#   Wind=Strong | size=5, entropy=0.971
#   IG = 0.072
# >>> Best feature = Outlook, score = 0.242
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Temperature, Parent entropy = 0.971
#   Temperature=Hot | size=2, entropy=0.000
#   Temperature=Mild | size=2, entropy=1.000
#   Temperature=Cool | size=1, entropy=0.000
#   IG = 0.571
#
# Feature: Humidity, Parent entropy = 0.971
#   Humidity=High | size=3, entropy=0.000
#   Humidity=Normal | size=2, entropy=0.000
#   IG = 0.971
#
# Feature: Wind, Parent entropy = 0.971
#   Wind=Weak | size=3, entropy=0.918
#   Wind=Strong | size=2, entropy=1.000
#   IG = 0.020
# >>> Best feature = Humidity, score = 0.971
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Temperature, Parent entropy = 1.000
#   Temperature=Mild | size=3, entropy=0.918
#   Temperature=Cool | size=1, entropy=0.000
#   IG = 0.311
#
# Feature: Humidity, Parent entropy = 1.000
#   Humidity=High | size=2, entropy=1.000
#   Humidity=Normal | size=2, entropy=1.000
#   IG = 0.000
#
# Feature: Wind, Parent entropy = 1.000
#   Wind=Weak | size=2, entropy=0.000
#   Wind=Strong | size=2, entropy=0.000
#   IG = 1.000
# >>> Best feature = Wind, score = 1.000
# Fold 2 | Acc=1.00, Macro-F1=1.00, Micro-F1=1.00
#
# ==================================================
# Depth 0 | Algorithm = ID3
#
# Feature: Outlook, Parent entropy = 0.918
#   Outlook=Sunny | size=5, entropy=0.971
#   Outlook=Rain | size=4, entropy=0.811
#   Outlook=Overcast | size=3, entropy=0.000
#   IG = 0.243
#
# Feature: Temperature, Parent entropy = 0.918
#   Temperature=Hot | size=3, entropy=0.918
#   Temperature=Mild | size=5, entropy=0.722
#   Temperature=Cool | size=4, entropy=0.811
#   IG = 0.117
#
# Feature: Humidity, Parent entropy = 0.918
#   Humidity=High | size=5, entropy=0.971
#   Humidity=Normal | size=7, entropy=0.592
#   IG = 0.169
#
# Feature: Wind, Parent entropy = 0.918
#   Wind=Weak | size=7, entropy=0.863
#   Wind=Strong | size=5, entropy=0.971
#   IG = 0.010
# >>> Best feature = Outlook, score = 0.243
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Temperature, Parent entropy = 0.971
#   Temperature=Hot | size=2, entropy=0.000
#   Temperature=Mild | size=2, entropy=1.000
#   Temperature=Cool | size=1, entropy=0.000
#   IG = 0.571
#
# Feature: Humidity, Parent entropy = 0.971
#   Humidity=High | size=3, entropy=0.000
#   Humidity=Normal | size=2, entropy=0.000
#   IG = 0.971
#
# Feature: Wind, Parent entropy = 0.971
#   Wind=Weak | size=3, entropy=0.918
#   Wind=Strong | size=2, entropy=1.000
#   IG = 0.020
# >>> Best feature = Humidity, score = 0.971
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Temperature, Parent entropy = 0.811
#   Temperature=Mild | size=2, entropy=0.000
#   Temperature=Cool | size=2, entropy=1.000
#   IG = 0.311
#
# Feature: Humidity, Parent entropy = 0.811
#   Humidity=High | size=1, entropy=0.000
#   Humidity=Normal | size=3, entropy=0.918
#   IG = 0.123
#
# Feature: Wind, Parent entropy = 0.811
#   Wind=Weak | size=3, entropy=0.000
#   Wind=Strong | size=1, entropy=0.000
#   IG = 0.811
# >>> Best feature = Wind, score = 0.811
# Fold 3 | Acc=1.00, Macro-F1=1.00, Micro-F1=1.00
#
# ==================================================
# Depth 0 | Algorithm = ID3
#
# Feature: Outlook, Parent entropy = 0.918
#   Outlook=Sunny | size=4, entropy=1.000
#   Outlook=Overcast | size=4, entropy=0.000
#   Outlook=Rain | size=4, entropy=1.000
#   IG = 0.252
#
# Feature: Temperature, Parent entropy = 0.918
#   Temperature=Hot | size=3, entropy=0.918
#   Temperature=Mild | size=5, entropy=0.971
#   Temperature=Cool | size=4, entropy=0.811
#   IG = 0.014
#
# Feature: Humidity, Parent entropy = 0.918
#   Humidity=High | size=6, entropy=1.000
#   Humidity=Normal | size=6, entropy=0.650
#   IG = 0.093
#
# Feature: Wind, Parent entropy = 0.918
#   Wind=Weak | size=7, entropy=0.863
#   Wind=Strong | size=5, entropy=0.971
#   IG = 0.010
# >>> Best feature = Outlook, score = 0.252
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Temperature, Parent entropy = 1.000
#   Temperature=Hot | size=1, entropy=0.000
#   Temperature=Mild | size=2, entropy=1.000
#   Temperature=Cool | size=1, entropy=0.000
#   IG = 0.500
#
# Feature: Humidity, Parent entropy = 1.000
#   Humidity=High | size=2, entropy=0.000
#   Humidity=Normal | size=2, entropy=0.000
#   IG = 1.000
#
# Feature: Wind, Parent entropy = 1.000
#   Wind=Weak | size=3, entropy=0.918
#   Wind=Strong | size=1, entropy=0.000
#   IG = 0.311
# >>> Best feature = Humidity, score = 1.000
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Temperature, Parent entropy = 1.000
#   Temperature=Mild | size=2, entropy=1.000
#   Temperature=Cool | size=2, entropy=1.000
#   IG = 0.000
#
# Feature: Humidity, Parent entropy = 1.000
#   Humidity=High | size=2, entropy=1.000
#   Humidity=Normal | size=2, entropy=1.000
#   IG = 0.000
#
# Feature: Wind, Parent entropy = 1.000
#   Wind=Weak | size=2, entropy=0.000
#   Wind=Strong | size=2, entropy=0.000
#   IG = 1.000
# >>> Best feature = Wind, score = 1.000
# Fold 4 | Acc=1.00, Macro-F1=1.00, Micro-F1=1.00
#
# ==================================================
# Depth 0 | Algorithm = ID3
#
# Feature: Outlook, Parent entropy = 0.918
#   Outlook=Sunny | size=3, entropy=0.918
#   Outlook=Overcast | size=4, entropy=0.000
#   Outlook=Rain | size=5, entropy=0.971
#   IG = 0.284
#
# Feature: Temperature, Parent entropy = 0.918
#   Temperature=Hot | size=4, entropy=1.000
#   Temperature=Mild | size=4, entropy=0.811
#   Temperature=Cool | size=4, entropy=0.811
#   IG = 0.044
#
# Feature: Humidity, Parent entropy = 0.918
#   Humidity=High | size=6, entropy=1.000
#   Humidity=Normal | size=6, entropy=0.650
#   IG = 0.093
#
# Feature: Wind, Parent entropy = 0.918
#   Wind=Weak | size=7, entropy=0.592
#   Wind=Strong | size=5, entropy=0.971
#   IG = 0.169
# >>> Best feature = Outlook, score = 0.284
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Temperature, Parent entropy = 0.918
#   Temperature=Hot | size=2, entropy=0.000
#   Temperature=Cool | size=1, entropy=0.000
#   IG = 0.918
#
# Feature: Humidity, Parent entropy = 0.918
#   Humidity=High | size=2, entropy=0.000
#   Humidity=Normal | size=1, entropy=0.000
#   IG = 0.918
#
# Feature: Wind, Parent entropy = 0.918
#   Wind=Weak | size=2, entropy=1.000
#   Wind=Strong | size=1, entropy=0.000
#   IG = 0.252
# >>> Best feature = Temperature, score = 0.918
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Temperature, Parent entropy = 0.971
#   Temperature=Mild | size=3, entropy=0.918
#   Temperature=Cool | size=2, entropy=1.000
#   IG = 0.020
#
# Feature: Humidity, Parent entropy = 0.971
#   Humidity=High | size=2, entropy=1.000
#   Humidity=Normal | size=3, entropy=0.918
#   IG = 0.020
#
# Feature: Wind, Parent entropy = 0.971
#   Wind=Weak | size=3, entropy=0.000
#   Wind=Strong | size=2, entropy=0.000
#   IG = 0.971
# >>> Best feature = Wind, score = 0.971
# Fold 5 | Acc=0.50, Macro-F1=0.33, Micro-F1=0.50
#
# === Final Results ( ID3 ) ===
# Avg Acc = 0.9
# Avg Macro-F1 = 0.8666666666666666
# Avg Micro-F1 = 0.9
#
# C4.5 Evaluation:
#
# ==================================================
# Depth 0 | Algorithm = C4.5
#
# Feature: Outlook, Parent entropy = 0.980
#   Outlook=Sunny | size=4, entropy=0.811
#   Outlook=Overcast | size=3, entropy=0.000
#   Outlook=Rain | size=5, entropy=0.971
#   IG = 0.305
#   SplitInfo = 1.555, GainRatio = 0.196
#
# Feature: Temperature, Parent entropy = 0.980
#   Temperature=Hot | size=4, entropy=1.000
#   Temperature=Mild | size=6, entropy=0.918
#   Temperature=Cool | size=2, entropy=1.000
#   IG = 0.021
#   SplitInfo = 1.459, GainRatio = 0.014
#
# Feature: Humidity, Parent entropy = 0.980
#   Humidity=High | size=7, entropy=0.985
#   Humidity=Normal | size=5, entropy=0.722
#   IG = 0.104
#   SplitInfo = 0.980, GainRatio = 0.106
#
# Feature: Wind, Parent entropy = 0.980
#   Wind=Weak | size=7, entropy=0.863
#   Wind=Strong | size=5, entropy=0.971
#   IG = 0.072
#   SplitInfo = 0.980, GainRatio = 0.073
# >>> Best feature = Outlook, score = 0.196
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Temperature, Parent entropy = 0.811
#   Temperature=Hot | size=2, entropy=0.000
#   Temperature=Mild | size=2, entropy=1.000
#   IG = 0.311
#   SplitInfo = 1.000, GainRatio = 0.311
#
# Feature: Humidity, Parent entropy = 0.811
#   Humidity=High | size=3, entropy=0.000
#   Humidity=Normal | size=1, entropy=0.000
#   IG = 0.811
#   SplitInfo = 0.811, GainRatio = 1.000
#
# Feature: Wind, Parent entropy = 0.811
#   Wind=Weak | size=2, entropy=0.000
#   Wind=Strong | size=2, entropy=1.000
#   IG = 0.311
#   SplitInfo = 1.000, GainRatio = 0.311
# >>> Best feature = Humidity, score = 1.000
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Temperature, Parent entropy = 0.971
#   Temperature=Mild | size=3, entropy=0.918
#   Temperature=Cool | size=2, entropy=1.000
#   IG = 0.020
#   SplitInfo = 0.971, GainRatio = 0.021
#
# Feature: Humidity, Parent entropy = 0.971
#   Humidity=High | size=2, entropy=1.000
#   Humidity=Normal | size=3, entropy=0.918
#   IG = 0.020
#   SplitInfo = 0.971, GainRatio = 0.021
#
# Feature: Wind, Parent entropy = 0.971
#   Wind=Weak | size=3, entropy=0.000
#   Wind=Strong | size=2, entropy=0.000
#   IG = 0.971
#   SplitInfo = 0.971, GainRatio = 1.000
# >>> Best feature = Wind, score = 1.000
# Fold 1 | Acc=1.00, Macro-F1=1.00, Micro-F1=1.00
#
# ==================================================
# Depth 0 | Algorithm = C4.5
#
# Feature: Outlook, Parent entropy = 0.980
#   Outlook=Sunny | size=5, entropy=0.971
#   Outlook=Overcast | size=3, entropy=0.000
#   Outlook=Rain | size=4, entropy=1.000
#   IG = 0.242
#   SplitInfo = 1.555, GainRatio = 0.156
#
# Feature: Temperature, Parent entropy = 0.980
#   Temperature=Hot | size=4, entropy=1.000
#   Temperature=Mild | size=5, entropy=0.971
#   Temperature=Cool | size=3, entropy=0.918
#   IG = 0.012
#   SplitInfo = 1.555, GainRatio = 0.008
#
# Feature: Humidity, Parent entropy = 0.980
#   Humidity=High | size=6, entropy=0.918
#   Humidity=Normal | size=6, entropy=0.650
#   IG = 0.196
#   SplitInfo = 1.000, GainRatio = 0.196
#
# Feature: Wind, Parent entropy = 0.980
#   Wind=Weak | size=7, entropy=0.863
#   Wind=Strong | size=5, entropy=0.971
#   IG = 0.072
#   SplitInfo = 0.980, GainRatio = 0.073
# >>> Best feature = Humidity, score = 0.196
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Outlook, Parent entropy = 0.918
#   Outlook=Sunny | size=3, entropy=0.000
#   Outlook=Overcast | size=1, entropy=0.000
#   Outlook=Rain | size=2, entropy=1.000
#   IG = 0.585
#   SplitInfo = 1.459, GainRatio = 0.401
#
# Feature: Temperature, Parent entropy = 0.918
#   Temperature=Hot | size=3, entropy=0.918
#   Temperature=Mild | size=3, entropy=0.918
#   IG = 0.000
#   SplitInfo = 1.000, GainRatio = 0.000
#
# Feature: Wind, Parent entropy = 0.918
#   Wind=Weak | size=4, entropy=1.000
#   Wind=Strong | size=2, entropy=0.000
#   IG = 0.252
#   SplitInfo = 0.918, GainRatio = 0.274
# >>> Best feature = Outlook, score = 0.401
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Temperature, Parent entropy = 1.000
#   Temperature=Mild | size=2, entropy=1.000
#   IG = 0.000
#   SplitInfo = 0.000, GainRatio = 0.000
#
# Feature: Wind, Parent entropy = 1.000
#   Wind=Weak | size=1, entropy=0.000
#   Wind=Strong | size=1, entropy=0.000
#   IG = 1.000
#   SplitInfo = 1.000, GainRatio = 1.000
# >>> Best feature = Wind, score = 1.000
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Outlook, Parent entropy = 0.650
#   Outlook=Rain | size=2, entropy=1.000
#   Outlook=Overcast | size=2, entropy=0.000
#   Outlook=Sunny | size=2, entropy=0.000
#   IG = 0.317
#   SplitInfo = 1.585, GainRatio = 0.200
#
# Feature: Temperature, Parent entropy = 0.650
#   Temperature=Cool | size=3, entropy=0.918
#   Temperature=Mild | size=2, entropy=0.000
#   Temperature=Hot | size=1, entropy=0.000
#   IG = 0.191
#   SplitInfo = 1.459, GainRatio = 0.131
#
# Feature: Wind, Parent entropy = 0.650
#   Wind=Strong | size=3, entropy=0.918
#   Wind=Weak | size=3, entropy=0.000
#   IG = 0.191
#   SplitInfo = 1.000, GainRatio = 0.191
# >>> Best feature = Outlook, score = 0.200
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Temperature, Parent entropy = 1.000
#   Temperature=Cool | size=1, entropy=0.000
#   Temperature=Mild | size=1, entropy=0.000
#   IG = 1.000
#   SplitInfo = 1.000, GainRatio = 1.000
#
# Feature: Wind, Parent entropy = 1.000
#   Wind=Strong | size=1, entropy=0.000
#   Wind=Weak | size=1, entropy=0.000
#   IG = 1.000
#   SplitInfo = 1.000, GainRatio = 1.000
# >>> Best feature = Temperature, score = 1.000
# Fold 2 | Acc=0.50, Macro-F1=0.67, Micro-F1=0.67
#
# ==================================================
# Depth 0 | Algorithm = C4.5
#
# Feature: Outlook, Parent entropy = 0.918
#   Outlook=Sunny | size=5, entropy=0.971
#   Outlook=Rain | size=4, entropy=0.811
#   Outlook=Overcast | size=3, entropy=0.000
#   IG = 0.243
#   SplitInfo = 1.555, GainRatio = 0.157
#
# Feature: Temperature, Parent entropy = 0.918
#   Temperature=Hot | size=3, entropy=0.918
#   Temperature=Mild | size=5, entropy=0.722
#   Temperature=Cool | size=4, entropy=0.811
#   IG = 0.117
#   SplitInfo = 1.555, GainRatio = 0.076
#
# Feature: Humidity, Parent entropy = 0.918
#   Humidity=High | size=5, entropy=0.971
#   Humidity=Normal | size=7, entropy=0.592
#   IG = 0.169
#   SplitInfo = 0.980, GainRatio = 0.172
#
# Feature: Wind, Parent entropy = 0.918
#   Wind=Weak | size=7, entropy=0.863
#   Wind=Strong | size=5, entropy=0.971
#   IG = 0.010
#   SplitInfo = 0.980, GainRatio = 0.010
# >>> Best feature = Humidity, score = 0.172
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Outlook, Parent entropy = 0.971
#   Outlook=Sunny | size=3, entropy=0.000
#   Outlook=Rain | size=1, entropy=0.000
#   Outlook=Overcast | size=1, entropy=0.000
#   IG = 0.971
#   SplitInfo = 1.371, GainRatio = 0.708
#
# Feature: Temperature, Parent entropy = 0.971
#   Temperature=Hot | size=2, entropy=0.000
#   Temperature=Mild | size=3, entropy=0.918
#   IG = 0.420
#   SplitInfo = 0.971, GainRatio = 0.433
#
# Feature: Wind, Parent entropy = 0.971
#   Wind=Weak | size=3, entropy=0.918
#   Wind=Strong | size=2, entropy=1.000
#   IG = 0.020
#   SplitInfo = 0.971, GainRatio = 0.021
# >>> Best feature = Outlook, score = 0.708
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Outlook, Parent entropy = 0.592
#   Outlook=Rain | size=3, entropy=0.918
#   Outlook=Overcast | size=2, entropy=0.000
#   Outlook=Sunny | size=2, entropy=0.000
#   IG = 0.198
#   SplitInfo = 1.557, GainRatio = 0.127
#
# Feature: Temperature, Parent entropy = 0.592
#   Temperature=Cool | size=4, entropy=0.811
#   Temperature=Mild | size=2, entropy=0.000
#   Temperature=Hot | size=1, entropy=0.000
#   IG = 0.128
#   SplitInfo = 1.379, GainRatio = 0.093
#
# Feature: Wind, Parent entropy = 0.592
#   Wind=Weak | size=4, entropy=0.000
#   Wind=Strong | size=3, entropy=0.918
#   IG = 0.198
#   SplitInfo = 0.985, GainRatio = 0.201
# >>> Best feature = Wind, score = 0.201
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Outlook, Parent entropy = 0.918
#   Outlook=Rain | size=1, entropy=0.000
#   Outlook=Overcast | size=1, entropy=0.000
#   Outlook=Sunny | size=1, entropy=0.000
#   IG = 0.918
#   SplitInfo = 1.585, GainRatio = 0.579
#
# Feature: Temperature, Parent entropy = 0.918
#   Temperature=Cool | size=2, entropy=1.000
#   Temperature=Mild | size=1, entropy=0.000
#   IG = 0.252
#   SplitInfo = 0.918, GainRatio = 0.274
# >>> Best feature = Outlook, score = 0.579
# Fold 3 | Acc=0.50, Macro-F1=0.33, Micro-F1=0.50
#
# ==================================================
# Depth 0 | Algorithm = C4.5
#
# Feature: Outlook, Parent entropy = 0.918
#   Outlook=Sunny | size=4, entropy=1.000
#   Outlook=Overcast | size=4, entropy=0.000
#   Outlook=Rain | size=4, entropy=1.000
#   IG = 0.252
#   SplitInfo = 1.585, GainRatio = 0.159
#
# Feature: Temperature, Parent entropy = 0.918
#   Temperature=Hot | size=3, entropy=0.918
#   Temperature=Mild | size=5, entropy=0.971
#   Temperature=Cool | size=4, entropy=0.811
#   IG = 0.014
#   SplitInfo = 1.555, GainRatio = 0.009
#
# Feature: Humidity, Parent entropy = 0.918
#   Humidity=High | size=6, entropy=1.000
#   Humidity=Normal | size=6, entropy=0.650
#   IG = 0.093
#   SplitInfo = 1.000, GainRatio = 0.093
#
# Feature: Wind, Parent entropy = 0.918
#   Wind=Weak | size=7, entropy=0.863
#   Wind=Strong | size=5, entropy=0.971
#   IG = 0.010
#   SplitInfo = 0.980, GainRatio = 0.010
# >>> Best feature = Outlook, score = 0.159
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Temperature, Parent entropy = 1.000
#   Temperature=Hot | size=1, entropy=0.000
#   Temperature=Mild | size=2, entropy=1.000
#   Temperature=Cool | size=1, entropy=0.000
#   IG = 0.500
#   SplitInfo = 1.500, GainRatio = 0.333
#
# Feature: Humidity, Parent entropy = 1.000
#   Humidity=High | size=2, entropy=0.000
#   Humidity=Normal | size=2, entropy=0.000
#   IG = 1.000
#   SplitInfo = 1.000, GainRatio = 1.000
#
# Feature: Wind, Parent entropy = 1.000
#   Wind=Weak | size=3, entropy=0.918
#   Wind=Strong | size=1, entropy=0.000
#   IG = 0.311
#   SplitInfo = 0.811, GainRatio = 0.384
# >>> Best feature = Humidity, score = 1.000
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Temperature, Parent entropy = 1.000
#   Temperature=Mild | size=2, entropy=1.000
#   Temperature=Cool | size=2, entropy=1.000
#   IG = 0.000
#   SplitInfo = 1.000, GainRatio = 0.000
#
# Feature: Humidity, Parent entropy = 1.000
#   Humidity=High | size=2, entropy=1.000
#   Humidity=Normal | size=2, entropy=1.000
#   IG = 0.000
#   SplitInfo = 1.000, GainRatio = 0.000
#
# Feature: Wind, Parent entropy = 1.000
#   Wind=Weak | size=2, entropy=0.000
#   Wind=Strong | size=2, entropy=0.000
#   IG = 1.000
#   SplitInfo = 1.000, GainRatio = 1.000
# >>> Best feature = Wind, score = 1.000
# Fold 4 | Acc=1.00, Macro-F1=1.00, Micro-F1=1.00
#
# ==================================================
# Depth 0 | Algorithm = C4.5
#
# Feature: Outlook, Parent entropy = 0.918
#   Outlook=Sunny | size=3, entropy=0.918
#   Outlook=Overcast | size=4, entropy=0.000
#   Outlook=Rain | size=5, entropy=0.971
#   IG = 0.284
#   SplitInfo = 1.555, GainRatio = 0.183
#
# Feature: Temperature, Parent entropy = 0.918
#   Temperature=Hot | size=4, entropy=1.000
#   Temperature=Mild | size=4, entropy=0.811
#   Temperature=Cool | size=4, entropy=0.811
#   IG = 0.044
#   SplitInfo = 1.585, GainRatio = 0.028
#
# Feature: Humidity, Parent entropy = 0.918
#   Humidity=High | size=6, entropy=1.000
#   Humidity=Normal | size=6, entropy=0.650
#   IG = 0.093
#   SplitInfo = 1.000, GainRatio = 0.093
#
# Feature: Wind, Parent entropy = 0.918
#   Wind=Weak | size=7, entropy=0.592
#   Wind=Strong | size=5, entropy=0.971
#   IG = 0.169
#   SplitInfo = 0.980, GainRatio = 0.172
# >>> Best feature = Outlook, score = 0.183
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Temperature, Parent entropy = 0.918
#   Temperature=Hot | size=2, entropy=0.000
#   Temperature=Cool | size=1, entropy=0.000
#   IG = 0.918
#   SplitInfo = 0.918, GainRatio = 1.000
#
# Feature: Humidity, Parent entropy = 0.918
#   Humidity=High | size=2, entropy=0.000
#   Humidity=Normal | size=1, entropy=0.000
#   IG = 0.918
#   SplitInfo = 0.918, GainRatio = 1.000
#
# Feature: Wind, Parent entropy = 0.918
#   Wind=Weak | size=2, entropy=1.000
#   Wind=Strong | size=1, entropy=0.000
#   IG = 0.252
#   SplitInfo = 0.918, GainRatio = 0.274
# >>> Best feature = Temperature, score = 1.000
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Temperature, Parent entropy = 0.971
#   Temperature=Mild | size=3, entropy=0.918
#   Temperature=Cool | size=2, entropy=1.000
#   IG = 0.020
#   SplitInfo = 0.971, GainRatio = 0.021
#
# Feature: Humidity, Parent entropy = 0.971
#   Humidity=High | size=2, entropy=1.000
#   Humidity=Normal | size=3, entropy=0.918
#   IG = 0.020
#   SplitInfo = 0.971, GainRatio = 0.021
#
# Feature: Wind, Parent entropy = 0.971
#   Wind=Weak | size=3, entropy=0.000
#   Wind=Strong | size=2, entropy=0.000
#   IG = 0.971
#   SplitInfo = 0.971, GainRatio = 1.000
# >>> Best feature = Wind, score = 1.000
# Fold 5 | Acc=0.50, Macro-F1=0.33, Micro-F1=0.50
#
# === Final Results ( C4.5 ) ===
# Avg Acc = 0.7
# Avg Macro-F1 = 0.6666666666666667
# Avg Micro-F1 = 0.7333333333333333

# %%
def print_tree(tree,indent=""):
    if tree["leaf"]:
        print(indent,"→",tree["label"])
    else:
        f = tree["feature"]
        for v,ch in tree["children"].items():
            print(indent,f,"=",v)
            print_tree(ch,indent+"   ")

print("\nFinal ID3 Tree on full data:")
id3_tree = build_tree(df_play.drop(columns=["Play"]), df_play["Play"], "ID3")
print_tree(id3_tree)

print("\nFinal C4.5 Tree on full data:")
c45_tree = build_tree(df_play.drop(columns=["Play"]), df_play["Play"], "C4.5")
print_tree(c45_tree)
# Out:
# Final ID3 Tree on full data:
#
# ==================================================
# Depth 0 | Algorithm = ID3
#
# Feature: Outlook, Parent entropy = 0.940
#   Outlook=Sunny | size=5, entropy=0.971
#   Outlook=Overcast | size=4, entropy=0.000
#   Outlook=Rain | size=5, entropy=0.971
#   IG = 0.247
#
# Feature: Temperature, Parent entropy = 0.940
#   Temperature=Hot | size=4, entropy=1.000
#   Temperature=Mild | size=6, entropy=0.918
#   Temperature=Cool | size=4, entropy=0.811
#   IG = 0.029
#
# Feature: Humidity, Parent entropy = 0.940
#   Humidity=High | size=7, entropy=0.985
#   Humidity=Normal | size=7, entropy=0.592
#   IG = 0.152
#
# Feature: Wind, Parent entropy = 0.940
#   Wind=Weak | size=8, entropy=0.811
#   Wind=Strong | size=6, entropy=1.000
#   IG = 0.048
# >>> Best feature = Outlook, score = 0.247
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Temperature, Parent entropy = 0.971
#   Temperature=Hot | size=2, entropy=0.000
#   Temperature=Mild | size=2, entropy=1.000
#   Temperature=Cool | size=1, entropy=0.000
#   IG = 0.571
#
# Feature: Humidity, Parent entropy = 0.971
#   Humidity=High | size=3, entropy=0.000
#   Humidity=Normal | size=2, entropy=0.000
#   IG = 0.971
#
# Feature: Wind, Parent entropy = 0.971
#   Wind=Weak | size=3, entropy=0.918
#   Wind=Strong | size=2, entropy=1.000
#   IG = 0.020
# >>> Best feature = Humidity, score = 0.971
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Temperature, Parent entropy = 0.971
#   Temperature=Mild | size=3, entropy=0.918
#   Temperature=Cool | size=2, entropy=1.000
#   IG = 0.020
#
# Feature: Humidity, Parent entropy = 0.971
#   Humidity=High | size=2, entropy=1.000
#   Humidity=Normal | size=3, entropy=0.918
#   IG = 0.020
#
# Feature: Wind, Parent entropy = 0.971
#   Wind=Weak | size=3, entropy=0.000
#   Wind=Strong | size=2, entropy=0.000
#   IG = 0.971
# >>> Best feature = Wind, score = 0.971
#  Outlook = Sunny
#     Humidity = High
#        → No
#     Humidity = Normal
#        → Yes
#  Outlook = Overcast
#     → Yes
#  Outlook = Rain
#     Wind = Weak
#        → Yes
#     Wind = Strong
#        → No
#
# Final C4.5 Tree on full data:
#
# ==================================================
# Depth 0 | Algorithm = C4.5
#
# Feature: Outlook, Parent entropy = 0.940
#   Outlook=Sunny | size=5, entropy=0.971
#   Outlook=Overcast | size=4, entropy=0.000
#   Outlook=Rain | size=5, entropy=0.971
#   IG = 0.247
#   SplitInfo = 1.577, GainRatio = 0.156
#
# Feature: Temperature, Parent entropy = 0.940
#   Temperature=Hot | size=4, entropy=1.000
#   Temperature=Mild | size=6, entropy=0.918
#   Temperature=Cool | size=4, entropy=0.811
#   IG = 0.029
#   SplitInfo = 1.557, GainRatio = 0.019
#
# Feature: Humidity, Parent entropy = 0.940
#   Humidity=High | size=7, entropy=0.985
#   Humidity=Normal | size=7, entropy=0.592
#   IG = 0.152
#   SplitInfo = 1.000, GainRatio = 0.152
#
# Feature: Wind, Parent entropy = 0.940
#   Wind=Weak | size=8, entropy=0.811
#   Wind=Strong | size=6, entropy=1.000
#   IG = 0.048
#   SplitInfo = 0.985, GainRatio = 0.049
# >>> Best feature = Outlook, score = 0.156
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Temperature, Parent entropy = 0.971
#   Temperature=Hot | size=2, entropy=0.000
#   Temperature=Mild | size=2, entropy=1.000
#   Temperature=Cool | size=1, entropy=0.000
#   IG = 0.571
#   SplitInfo = 1.522, GainRatio = 0.375
#
# Feature: Humidity, Parent entropy = 0.971
#   Humidity=High | size=3, entropy=0.000
#   Humidity=Normal | size=2, entropy=0.000
#   IG = 0.971
#   SplitInfo = 0.971, GainRatio = 1.000
#
# Feature: Wind, Parent entropy = 0.971
#   Wind=Weak | size=3, entropy=0.918
#   Wind=Strong | size=2, entropy=1.000
#   IG = 0.020
#   SplitInfo = 0.971, GainRatio = 0.021
# >>> Best feature = Humidity, score = 1.000
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Temperature, Parent entropy = 0.971
#   Temperature=Mild | size=3, entropy=0.918
#   Temperature=Cool | size=2, entropy=1.000
#   IG = 0.020
#   SplitInfo = 0.971, GainRatio = 0.021
#
# Feature: Humidity, Parent entropy = 0.971
#   Humidity=High | size=2, entropy=1.000
#   Humidity=Normal | size=3, entropy=0.918
#   IG = 0.020
#   SplitInfo = 0.971, GainRatio = 0.021
#
# Feature: Wind, Parent entropy = 0.971
#   Wind=Weak | size=3, entropy=0.000
#   Wind=Strong | size=2, entropy=0.000
#   IG = 0.971
#   SplitInfo = 0.971, GainRatio = 1.000
# >>> Best feature = Wind, score = 1.000
#  Outlook = Sunny
#     Humidity = High
#        → No
#     Humidity = Normal
#        → Yes
#  Outlook = Overcast
#     → Yes
#  Outlook = Rain
#     Wind = Weak
#        → Yes
#     Wind = Strong
#        → No
