# %%
import pandas as pd
import numpy as np
from collections import Counter
from math import log2

# Load CSV (already cleaned)
df_drug = pd.read_csv("drug_200.csv")

print("Dataset shape:", df_drug.shape)
df_drug.head()
# Out:
# Dataset shape: (200, 6)
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  drugY

# %%
from sklearn.preprocessing import LabelEncoder

# Encode categorical columns
le_dict = {}
for col in ["Sex","BP","Cholesterol","Drug"]:   # leave Age, Na_to_K as numeric
    le = LabelEncoder()
    df_drug[col] = le.fit_transform(df_drug[col])
    le_dict[col] = le

print("Unique classes for Drug:", le_dict["Drug"].classes_)
df_drug.head()
# Out:
# Unique classes for Drug: ['drugA' 'drugB' 'drugC' 'drugX' 'drugY']
#    Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0   23    0   0            0   25.355     4
# 1   47    1   1            0   13.093     2
# 2   47    1   1            0   10.114     2
# 3   28    0   2            0    7.798     3
# 4   61    0   1            0   18.043     4

# %%
def entropy(y):
    total = len(y)
    counts = Counter(y)
    return -sum((c/total)*log2(c/total) for c in counts.values())

# %%
def info_gain(X, y, feature, verbose=True):
    base = entropy(y)
    n = len(y)
    best_ig, best_split = 0, None
    if verbose:
        print(f"\nFeature: {feature}, Parent entropy = {base:.3f}")

    if X[feature].dtype in [np.int64,np.float64] and feature in ["Age","Na_to_K"]:
        values = sorted(X[feature].unique())
        for t in values:
            left, right = y[X[feature]<=t], y[X[feature]>t]
            if len(left)==0 or len(right)==0: continue
            weighted = (len(left)/n)*entropy(left) + (len(right)/n)*entropy(right)
            ig = base - weighted
            if ig > best_ig:
                best_ig, best_split = ig, t
        if verbose: print(f"  Best split at {best_split}, IG = {best_ig:.3f}")
        return best_ig, best_split
    else:
        weighted = 0
        for v in X[feature].unique():
            sub = y[X[feature]==v]
            e = entropy(sub)
            weighted += (len(sub)/n)*e
            if verbose:
                print(f"  {feature}={v} | size={len(sub)}, entropy={e:.3f}")
        ig = base - weighted
        if verbose: print(f"  IG = {ig:.3f}")
        return ig, None

def split_info(X, feature, threshold=None):
    n = len(X)
    si = 0
    if threshold is None:
        for v in X[feature].unique():
            p = len(X[X[feature]==v])/n
            if p>0: si -= p*log2(p)
    else:
        left = len(X[X[feature]<=threshold])/n
        right = len(X[X[feature]>threshold])/n
        for p in [left,right]:
            if p>0: si -= p*log2(p)
    return si

def gain_ratio(X, y, feature, verbose=True):
    ig, t = info_gain(X,y,feature,verbose)
    si = split_info(X,feature,t)
    gr = ig/si if si>0 else 0
    if verbose:
        print(f"  SplitInfo = {si:.3f}, GainRatio = {gr:.3f}")
    return gr, t

# %%
def most_common(y):
    return Counter(y).most_common(1)[0][0]

def build_tree(X,y,algo="ID3",depth=0):
    if len(set(y))==1:
        return {"leaf":True,"label":y.iloc[0]}
    if X.shape[1]==0:
        return {"leaf":True,"label":most_common(y)}

    print("\n" + "="*50)
    print(f"Depth {depth} | Algorithm = {algo}")

    best_feat, best_score, best_thresh = None,-1,None
    for f in X.columns:
        if algo=="ID3":
            score,th = info_gain(X,y,f,True)
        else:
            score,th = gain_ratio(X,y,f,True)
        if score > best_score:
            best_feat, best_score, best_thresh = f, score, th
    print(f">>> Best feature = {best_feat}, threshold = {best_thresh}, score = {best_score:.3f}")

    node = {"leaf":False,"feature":best_feat,"threshold":best_thresh,"children":{}}
    if best_thresh is None:
        for v in X[best_feat].unique():
            mask = (X[best_feat]==v)
            child = build_tree(X[mask].drop(columns=[best_feat]), y[mask], algo, depth+1)
            node["children"][v] = child
    else:
        mask_left = (X[best_feat]<=best_thresh)
        mask_right = (X[best_feat]>best_thresh)
        node["children"]["<="] = build_tree(X[mask_left], y[mask_left], algo, depth+1)
        node["children"][">"] = build_tree(X[mask_right], y[mask_right], algo, depth+1)
    return node

# %%
def predict_one(tree,row):
    if tree["leaf"]: return tree["label"]
    f,th = tree["feature"], tree["threshold"]
    if th is None:
        v = row[f]
        if v in tree["children"]:
            return predict_one(tree["children"][v], row)
        else:
            return most_common([c["label"] for c in tree["children"].values() if c["leaf"]])
    else:
        if row[f]<=th:
            return predict_one(tree["children"]["<="], row)
        else:
            return predict_one(tree["children"][">"], row)

def predict(tree,X):
    return [predict_one(tree,row) for _,row in X.iterrows()]

# %%
def accuracy(y_true,y_pred):
    return np.mean(np.array(y_true)==np.array(y_pred))

def precision_recall_f1(y_true,y_pred):
    labels = sorted(set(y_true))
    per_class = {}
    micro_tp = micro_fp = micro_fn = 0
    for l in labels:
        tp = sum((y_true==l)&(y_pred==l))
        fp = sum((y_true!=l)&(y_pred==l))
        fn = sum((y_true==l)&(y_pred!=l))
        p = tp/(tp+fp) if tp+fp>0 else 0
        r = tp/(tp+fn) if tp+fn>0 else 0
        f = (2*p*r)/(p+r) if p+r>0 else 0
        per_class[l] = (p,r,f)
        micro_tp += tp; micro_fp += fp; micro_fn += fn

    macro_f = np.mean([v[2] for v in per_class.values()])
    micro_p = micro_tp/(micro_tp+micro_fp) if micro_tp+micro_fp>0 else 0
    micro_r = micro_tp/(micro_tp+micro_fn) if micro_tp+micro_fn>0 else 0
    micro_f = (2*micro_p*micro_r)/(micro_p+micro_r) if micro_p+micro_r>0 else 0

    return per_class, macro_f, micro_f

# %%
def manual_kfold(df,k=5,target="Drug",algo="ID3"):
    X = df.drop(columns=[target])
    y = df[target].reset_index(drop=True)
    n = len(df)
    idx = np.arange(n)
    np.random.seed(0)
    np.random.shuffle(idx)

    fold_size = n//k
    accs, macros, micros = [], [], []
    for i in range(k):
        start, end = i*fold_size,(i+1)*fold_size
        test_idx = idx[start:end]
        train_idx = np.setdiff1d(idx,test_idx)

        Xtr,ytr = X.iloc[train_idx], y.iloc[train_idx]
        Xte,yte = X.iloc[test_idx], y.iloc[test_idx]

        tree = build_tree(Xtr,ytr,algo)
        ypred = np.array(predict(tree,Xte))

        acc = accuracy(yte.values, ypred)
        _, macro, micro = precision_recall_f1(yte.values, ypred)
        accs.append(acc); macros.append(macro); micros.append(micro)

        print(f"Fold {i+1} | Acc={acc:.2f}, Macro-F1={macro:.2f}, Micro-F1={micro:.2f}")

    print("\n=== Final Results (",algo,") ===")
    print("Avg Acc =", np.mean(accs))
    print("Avg Macro-F1 =", np.mean(macros))
    print("Avg Micro-F1 =", np.mean(micros))

print("\nID3 Evaluation:")
manual_kfold(df_drug,5,"Drug","ID3")

print("\nC4.5 Evaluation:")
manual_kfold(df_drug,5,"Drug","C4.5")
# Out:
# ID3 Evaluation:
#
# ==================================================
# Depth 0 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 2.008
#   Best split at 50, IG = 0.218
#
# Feature: Sex, Parent entropy = 2.008
#   Sex=0 | size=75, entropy=1.924
#   Sex=1 | size=85, entropy=2.070
#   IG = 0.006
#
# Feature: BP, Parent entropy = 2.008
#   BP=0 | size=66, entropy=1.520
#   BP=1 | size=50, entropy=1.519
#   BP=2 | size=44, entropy=0.962
#   IG = 0.642
#
# Feature: Cholesterol, Parent entropy = 2.008
#   Cholesterol=0 | size=86, entropy=2.060
#   Cholesterol=1 | size=74, entropy=1.742
#   IG = 0.095
#
# Feature: Na_to_K, Parent entropy = 2.008
#   Best split at 14.642, IG = 0.993
# >>> Best feature = Na_to_K, threshold = 14.642, score = 0.993
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 1.846
#   Best split at 50, IG = 0.397
#
# Feature: Sex, Parent entropy = 1.846
#   Sex=1 | size=50, entropy=1.858
#   Sex=0 | size=38, entropy=1.825
#   IG = 0.002
#
# Feature: BP, Parent entropy = 1.846
#   BP=1 | size=26, entropy=1.000
#   BP=2 | size=27, entropy=-0.000
#   BP=0 | size=35, entropy=0.985
#   IG = 1.158
#
# Feature: Cholesterol, Parent entropy = 1.846
#   Cholesterol=0 | size=47, entropy=1.951
#   Cholesterol=1 | size=41, entropy=1.355
#   IG = 0.172
#
# Feature: Na_to_K, Parent entropy = 1.846
#   Best split at 13.313, IG = 0.058
# >>> Best feature = BP, threshold = None, score = 1.158
#
# ==================================================
# Depth 2 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 1.000
#   Best split at 28, IG = 0.126
#
# Feature: Sex, Parent entropy = 1.000
#   Sex=1 | size=15, entropy=0.997
#   Sex=0 | size=11, entropy=0.994
#   IG = 0.004
#
# Feature: Cholesterol, Parent entropy = 1.000
#   Cholesterol=0 | size=13, entropy=-0.000
#   Cholesterol=1 | size=13, entropy=-0.000
#   IG = 1.000
#
# Feature: Na_to_K, Parent entropy = 1.000
#   Best split at 13.127, IG = 0.126
# >>> Best feature = Cholesterol, threshold = None, score = 1.000
#
# ==================================================
# Depth 2 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 0.985
#   Best split at 50, IG = 0.985
#
# Feature: Sex, Parent entropy = 0.985
#   Sex=1 | size=21, entropy=0.985
#   Sex=0 | size=14, entropy=0.985
#   IG = 0.000
#
# Feature: Cholesterol, Parent entropy = 0.985
#   Cholesterol=0 | size=19, entropy=0.949
#   Cholesterol=1 | size=16, entropy=1.000
#   IG = 0.013
#
# Feature: Na_to_K, Parent entropy = 0.985
#   Best split at 8.011, IG = 0.074
# >>> Best feature = Age, threshold = 50, score = 0.985
# Fold 1 | Acc=1.00, Macro-F1=1.00, Micro-F1=1.00
#
# ==================================================
# Depth 0 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 1.999
#   Best split at 50, IG = 0.197
#
# Feature: Sex, Parent entropy = 1.999
#   Sex=0 | size=69, entropy=1.888
#   Sex=1 | size=91, entropy=2.064
#   IG = 0.010
#
# Feature: BP, Parent entropy = 1.999
#   BP=0 | size=61, entropy=1.498
#   BP=1 | size=54, entropy=1.547
#   BP=2 | size=45, entropy=0.956
#   IG = 0.636
#
# Feature: Cholesterol, Parent entropy = 1.999
#   Cholesterol=0 | size=81, entropy=2.084
#   Cholesterol=1 | size=79, entropy=1.677
#   IG = 0.116
#
# Feature: Na_to_K, Parent entropy = 1.999
#   Best split at 14.239, IG = 0.991
# >>> Best feature = Na_to_K, threshold = 14.239, score = 0.991
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 1.812
#   Best split at 50, IG = 0.354
#
# Feature: Sex, Parent entropy = 1.812
#   Sex=1 | size=54, entropy=1.836
#   Sex=0 | size=35, entropy=1.752
#   IG = 0.009
#
# Feature: BP, Parent entropy = 1.812
#   BP=1 | size=30, entropy=1.000
#   BP=2 | size=28, entropy=-0.000
#   BP=0 | size=31, entropy=0.981
#   IG = 1.133
#
# Feature: Cholesterol, Parent entropy = 1.812
#   Cholesterol=0 | size=46, entropy=1.932
#   Cholesterol=1 | size=43, entropy=1.253
#   IG = 0.208
#
# Feature: Na_to_K, Parent entropy = 1.812
#   Best split at 9.514, IG = 0.065
# >>> Best feature = BP, threshold = None, score = 1.133
#
# ==================================================
# Depth 2 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 1.000
#   Best split at 28, IG = 0.055
#
# Feature: Sex, Parent entropy = 1.000
#   Sex=1 | size=17, entropy=0.998
#   Sex=0 | size=13, entropy=0.996
#   IG = 0.003
#
# Feature: Cholesterol, Parent entropy = 1.000
#   Cholesterol=0 | size=15, entropy=-0.000
#   Cholesterol=1 | size=15, entropy=-0.000
#   IG = 1.000
#
# Feature: Na_to_K, Parent entropy = 1.000
#   Best split at 7.298, IG = 0.070
# >>> Best feature = Cholesterol, threshold = None, score = 1.000
#
# ==================================================
# Depth 2 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 0.981
#   Best split at 50, IG = 0.981
#
# Feature: Sex, Parent entropy = 0.981
#   Sex=1 | size=21, entropy=0.985
#   Sex=0 | size=10, entropy=0.971
#   IG = 0.001
#
# Feature: Cholesterol, Parent entropy = 0.981
#   Cholesterol=0 | size=16, entropy=1.000
#   Cholesterol=1 | size=15, entropy=0.918
#   IG = 0.021
#
# Feature: Na_to_K, Parent entropy = 0.981
#   Best split at 13.313, IG = 0.084
# >>> Best feature = Age, threshold = 50, score = 0.981
# Fold 2 | Acc=0.97, Macro-F1=0.99, Micro-F1=0.97
#
# ==================================================
# Depth 0 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 1.882
#   Best split at 49, IG = 0.159
#
# Feature: Sex, Parent entropy = 1.882
#   Sex=1 | size=83, entropy=1.989
#   Sex=0 | size=77, entropy=1.735
#   IG = 0.016
#
# Feature: BP, Parent entropy = 1.882
#   BP=1 | size=49, entropy=1.519
#   BP=2 | size=53, entropy=0.956
#   BP=0 | size=58, entropy=1.405
#   IG = 0.591
#
# Feature: Cholesterol, Parent entropy = 1.882
#   Cholesterol=0 | size=75, entropy=1.975
#   Cholesterol=1 | size=85, entropy=1.636
#   IG = 0.088
#
# Feature: Na_to_K, Parent entropy = 1.882
#   Best split at 14.642, IG = 0.996
# >>> Best feature = Na_to_K, threshold = 14.642, score = 0.996
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 1.649
#   Best split at 49, IG = 0.290
#
# Feature: Sex, Parent entropy = 1.649
#   Sex=1 | size=46, entropy=1.799
#   Sex=0 | size=40, entropy=1.417
#   IG = 0.028
#
# Feature: BP, Parent entropy = 1.649
#   BP=1 | size=26, entropy=0.983
#   BP=2 | size=33, entropy=-0.000
#   BP=0 | size=27, entropy=0.877
#   IG = 1.077
#
# Feature: Cholesterol, Parent entropy = 1.649
#   Cholesterol=0 | size=40, entropy=1.833
#   Cholesterol=1 | size=46, entropy=1.184
#   IG = 0.163
#
# Feature: Na_to_K, Parent entropy = 1.649
#   Best split at 8.607, IG = 0.060
# >>> Best feature = BP, threshold = None, score = 1.077
#
# ==================================================
# Depth 2 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 0.983
#   Best split at 28, IG = 0.102
#
# Feature: Sex, Parent entropy = 0.983
#   Sex=1 | size=14, entropy=1.000
#   Sex=0 | size=12, entropy=0.918
#   IG = 0.021
#
# Feature: Cholesterol, Parent entropy = 0.983
#   Cholesterol=0 | size=11, entropy=-0.000
#   Cholesterol=1 | size=15, entropy=-0.000
#   IG = 0.983
#
# Feature: Na_to_K, Parent entropy = 0.983
#   Best split at 7.298, IG = 0.102
# >>> Best feature = Cholesterol, threshold = None, score = 0.983
#
# ==================================================
# Depth 2 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 0.877
#   Best split at 49, IG = 0.877
#
# Feature: Sex, Parent entropy = 0.877
#   Sex=1 | size=17, entropy=0.937
#   Sex=0 | size=10, entropy=0.722
#   IG = 0.020
#
# Feature: Cholesterol, Parent entropy = 0.877
#   Cholesterol=0 | size=12, entropy=0.918
#   Cholesterol=1 | size=15, entropy=0.837
#   IG = 0.004
#
# Feature: Na_to_K, Parent entropy = 0.877
#   Best split at 13.313, IG = 0.054
# >>> Best feature = Age, threshold = 49, score = 0.877
# Fold 3 | Acc=0.97, Macro-F1=0.96, Micro-F1=0.97
#
# ==================================================
# Depth 0 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 1.997
#   Best split at 50, IG = 0.216
#
# Feature: Sex, Parent entropy = 1.997
#   Sex=0 | size=81, entropy=1.859
#   Sex=1 | size=79, entropy=2.106
#   IG = 0.016
#
# Feature: BP, Parent entropy = 1.997
#   BP=0 | size=63, entropy=1.534
#   BP=1 | size=51, entropy=1.507
#   BP=2 | size=46, entropy=0.950
#   IG = 0.639
#
# Feature: Cholesterol, Parent entropy = 1.997
#   Cholesterol=0 | size=87, entropy=2.035
#   Cholesterol=1 | size=73, entropy=1.776
#   IG = 0.080
#
# Feature: Na_to_K, Parent entropy = 1.997
#   Best split at 14.642, IG = 0.991
# >>> Best feature = Na_to_K, threshold = 14.642, score = 0.991
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 1.808
#   Best split at 50, IG = 0.388
#
# Feature: Sex, Parent entropy = 1.808
#   Sex=1 | size=47, entropy=1.903
#   Sex=0 | size=42, entropy=1.659
#   IG = 0.021
#
# Feature: BP, Parent entropy = 1.808
#   BP=1 | size=26, entropy=0.996
#   BP=2 | size=29, entropy=-0.000
#   BP=0 | size=34, entropy=0.998
#   IG = 1.136
#
# Feature: Cholesterol, Parent entropy = 1.808
#   Cholesterol=0 | size=47, entropy=1.925
#   Cholesterol=1 | size=42, entropy=1.377
#   IG = 0.142
#
# Feature: Na_to_K, Parent entropy = 1.808
#   Best split at 13.091, IG = 0.072
# >>> Best feature = BP, threshold = None, score = 1.136
#
# ==================================================
# Depth 2 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 0.996
#   Best split at 26, IG = 0.083
#
# Feature: Sex, Parent entropy = 0.996
#   Sex=1 | size=14, entropy=1.000
#   Sex=0 | size=12, entropy=0.980
#   IG = 0.005
#
# Feature: Cholesterol, Parent entropy = 0.996
#   Cholesterol=0 | size=12, entropy=-0.000
#   Cholesterol=1 | size=14, entropy=-0.000
#   IG = 0.996
#
# Feature: Na_to_K, Parent entropy = 0.996
#   Best split at 10.444, IG = 0.105
# >>> Best feature = Cholesterol, threshold = None, score = 0.996
#
# ==================================================
# Depth 2 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 0.998
#   Best split at 50, IG = 0.998
#
# Feature: Sex, Parent entropy = 0.998
#   Sex=1 | size=21, entropy=0.998
#   Sex=0 | size=13, entropy=0.996
#   IG = 0.000
#
# Feature: Cholesterol, Parent entropy = 0.998
#   Cholesterol=0 | size=17, entropy=0.998
#   Cholesterol=1 | size=17, entropy=0.998
#   IG = 0.000
#
# Feature: Na_to_K, Parent entropy = 0.998
#   Best split at 13.091, IG = 0.181
# >>> Best feature = Age, threshold = 50, score = 0.998
# Fold 4 | Acc=1.00, Macro-F1=1.00, Micro-F1=1.00
#
# ==================================================
# Depth 0 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 1.935
#   Best split at 50, IG = 0.191
#
# Feature: Sex, Parent entropy = 1.935
#   Sex=0 | size=82, entropy=1.864
#   Sex=1 | size=78, entropy=1.999
#   IG = 0.005
#
# Feature: BP, Parent entropy = 1.935
#   BP=0 | size=60, entropy=1.472
#   BP=1 | size=52, entropy=1.532
#   BP=2 | size=48, entropy=0.989
#   IG = 0.588
#
# Feature: Cholesterol, Parent entropy = 1.935
#   Cholesterol=0 | size=83, entropy=2.008
#   Cholesterol=1 | size=77, entropy=1.640
#   IG = 0.104
#
# Feature: Na_to_K, Parent entropy = 1.935
#   Best split at 14.642, IG = 0.998
# >>> Best feature = Na_to_K, threshold = 14.642, score = 0.998
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 1.784
#   Best split at 50, IG = 0.364
#
# Feature: Sex, Parent entropy = 1.784
#   Sex=1 | size=43, entropy=1.826
#   Sex=0 | size=41, entropy=1.729
#   IG = 0.006
#
# Feature: BP, Parent entropy = 1.784
#   BP=1 | size=28, entropy=0.996
#   BP=2 | size=27, entropy=-0.000
#   BP=0 | size=29, entropy=0.978
#   IG = 1.114
#
# Feature: Cholesterol, Parent entropy = 1.784
#   Cholesterol=0 | size=44, entropy=1.906
#   Cholesterol=1 | size=40, entropy=1.233
#   IG = 0.199
#
# Feature: Na_to_K, Parent entropy = 1.784
#   Best split at 9.664, IG = 0.079
# >>> Best feature = BP, threshold = None, score = 1.114
#
# ==================================================
# Depth 2 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 0.996
#   Best split at 59, IG = 0.143
#
# Feature: Sex, Parent entropy = 0.996
#   Sex=1 | size=16, entropy=0.989
#   Sex=0 | size=12, entropy=1.000
#   IG = 0.003
#
# Feature: Cholesterol, Parent entropy = 0.996
#   Cholesterol=0 | size=13, entropy=-0.000
#   Cholesterol=1 | size=15, entropy=-0.000
#   IG = 0.996
#
# Feature: Na_to_K, Parent entropy = 0.996
#   Best split at 8.151, IG = 0.084
# >>> Best feature = Cholesterol, threshold = None, score = 0.996
#
# ==================================================
# Depth 2 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 0.978
#   Best split at 50, IG = 0.978
#
# Feature: Sex, Parent entropy = 0.978
#   Sex=1 | size=16, entropy=0.954
#   Sex=0 | size=13, entropy=0.996
#   IG = 0.006
#
# Feature: Cholesterol, Parent entropy = 0.978
#   Cholesterol=0 | size=16, entropy=0.896
#   Cholesterol=1 | size=13, entropy=0.996
#   IG = 0.038
#
# Feature: Na_to_K, Parent entropy = 0.978
#   Best split at 9.664, IG = 0.151
# >>> Best feature = Age, threshold = 50, score = 0.978
# Fold 5 | Acc=1.00, Macro-F1=1.00, Micro-F1=1.00
#
# === Final Results ( ID3 ) ===
# Avg Acc = 0.99
# Avg Macro-F1 = 0.9890524014483842
# Avg Micro-F1 = 0.99
#
# C4.5 Evaluation:
#
# ==================================================
# Depth 0 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 2.008
#   Best split at 50, IG = 0.218
#   SplitInfo = 0.963, GainRatio = 0.227
#
# Feature: Sex, Parent entropy = 2.008
#   Sex=0 | size=75, entropy=1.924
#   Sex=1 | size=85, entropy=2.070
#   IG = 0.006
#   SplitInfo = 0.997, GainRatio = 0.006
#
# Feature: BP, Parent entropy = 2.008
#   BP=0 | size=66, entropy=1.520
#   BP=1 | size=50, entropy=1.519
#   BP=2 | size=44, entropy=0.962
#   IG = 0.642
#   SplitInfo = 1.564, GainRatio = 0.410
#
# Feature: Cholesterol, Parent entropy = 2.008
#   Cholesterol=0 | size=86, entropy=2.060
#   Cholesterol=1 | size=74, entropy=1.742
#   IG = 0.095
#   SplitInfo = 0.996, GainRatio = 0.095
#
# Feature: Na_to_K, Parent entropy = 2.008
#   Best split at 14.642, IG = 0.993
#   SplitInfo = 0.993, GainRatio = 1.000
# >>> Best feature = Na_to_K, threshold = 14.642, score = 1.000
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 1.846
#   Best split at 50, IG = 0.397
#   SplitInfo = 0.962, GainRatio = 0.413
#
# Feature: Sex, Parent entropy = 1.846
#   Sex=1 | size=50, entropy=1.858
#   Sex=0 | size=38, entropy=1.825
#   IG = 0.002
#   SplitInfo = 0.987, GainRatio = 0.002
#
# Feature: BP, Parent entropy = 1.846
#   BP=1 | size=26, entropy=1.000
#   BP=2 | size=27, entropy=-0.000
#   BP=0 | size=35, entropy=0.985
#   IG = 1.158
#   SplitInfo = 1.572, GainRatio = 0.737
#
# Feature: Cholesterol, Parent entropy = 1.846
#   Cholesterol=0 | size=47, entropy=1.951
#   Cholesterol=1 | size=41, entropy=1.355
#   IG = 0.172
#   SplitInfo = 0.997, GainRatio = 0.173
#
# Feature: Na_to_K, Parent entropy = 1.846
#   Best split at 13.313, IG = 0.058
#   SplitInfo = 0.575, GainRatio = 0.102
# >>> Best feature = BP, threshold = None, score = 0.737
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 1.000
#   Best split at 28, IG = 0.126
#   SplitInfo = 0.516, GainRatio = 0.245
#
# Feature: Sex, Parent entropy = 1.000
#   Sex=1 | size=15, entropy=0.997
#   Sex=0 | size=11, entropy=0.994
#   IG = 0.004
#   SplitInfo = 0.983, GainRatio = 0.004
#
# Feature: Cholesterol, Parent entropy = 1.000
#   Cholesterol=0 | size=13, entropy=-0.000
#   Cholesterol=1 | size=13, entropy=-0.000
#   IG = 1.000
#   SplitInfo = 1.000, GainRatio = 1.000
#
# Feature: Na_to_K, Parent entropy = 1.000
#   Best split at 13.127, IG = 0.126
#   SplitInfo = 0.516, GainRatio = 0.245
# >>> Best feature = Cholesterol, threshold = None, score = 1.000
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 0.985
#   Best split at 50, IG = 0.985
#   SplitInfo = 0.985, GainRatio = 1.000
#
# Feature: Sex, Parent entropy = 0.985
#   Sex=1 | size=21, entropy=0.985
#   Sex=0 | size=14, entropy=0.985
#   IG = 0.000
#   SplitInfo = 0.971, GainRatio = 0.000
#
# Feature: Cholesterol, Parent entropy = 0.985
#   Cholesterol=0 | size=19, entropy=0.949
#   Cholesterol=1 | size=16, entropy=1.000
#   IG = 0.013
#   SplitInfo = 0.995, GainRatio = 0.013
#
# Feature: Na_to_K, Parent entropy = 0.985
#   Best split at 8.011, IG = 0.074
#   SplitInfo = 0.422, GainRatio = 0.174
# >>> Best feature = Age, threshold = 50, score = 1.000
# Fold 1 | Acc=1.00, Macro-F1=1.00, Micro-F1=1.00
#
# ==================================================
# Depth 0 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 1.999
#   Best split at 50, IG = 0.197
#   SplitInfo = 0.928, GainRatio = 0.212
#
# Feature: Sex, Parent entropy = 1.999
#   Sex=0 | size=69, entropy=1.888
#   Sex=1 | size=91, entropy=2.064
#   IG = 0.010
#   SplitInfo = 0.986, GainRatio = 0.011
#
# Feature: BP, Parent entropy = 1.999
#   BP=0 | size=61, entropy=1.498
#   BP=1 | size=54, entropy=1.547
#   BP=2 | size=45, entropy=0.956
#   IG = 0.636
#   SplitInfo = 1.574, GainRatio = 0.404
#
# Feature: Cholesterol, Parent entropy = 1.999
#   Cholesterol=0 | size=81, entropy=2.084
#   Cholesterol=1 | size=79, entropy=1.677
#   IG = 0.116
#   SplitInfo = 1.000, GainRatio = 0.116
#
# Feature: Na_to_K, Parent entropy = 1.999
#   Best split at 14.239, IG = 0.991
#   SplitInfo = 0.991, GainRatio = 1.000
# >>> Best feature = Na_to_K, threshold = 14.239, score = 1.000
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 1.812
#   Best split at 50, IG = 0.354
#   SplitInfo = 0.922, GainRatio = 0.384
#
# Feature: Sex, Parent entropy = 1.812
#   Sex=1 | size=54, entropy=1.836
#   Sex=0 | size=35, entropy=1.752
#   IG = 0.009
#   SplitInfo = 0.967, GainRatio = 0.010
#
# Feature: BP, Parent entropy = 1.812
#   BP=1 | size=30, entropy=1.000
#   BP=2 | size=28, entropy=-0.000
#   BP=0 | size=31, entropy=0.981
#   IG = 1.133
#   SplitInfo = 1.584, GainRatio = 0.715
#
# Feature: Cholesterol, Parent entropy = 1.812
#   Cholesterol=0 | size=46, entropy=1.932
#   Cholesterol=1 | size=43, entropy=1.253
#   IG = 0.208
#   SplitInfo = 0.999, GainRatio = 0.208
#
# Feature: Na_to_K, Parent entropy = 1.812
#   Best split at 9.514, IG = 0.065
#   SplitInfo = 0.871, GainRatio = 0.075
# >>> Best feature = BP, threshold = None, score = 0.715
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 1.000
#   Best split at 28, IG = 0.055
#   SplitInfo = 0.650, GainRatio = 0.085
#
# Feature: Sex, Parent entropy = 1.000
#   Sex=1 | size=17, entropy=0.998
#   Sex=0 | size=13, entropy=0.996
#   IG = 0.003
#   SplitInfo = 0.987, GainRatio = 0.003
#
# Feature: Cholesterol, Parent entropy = 1.000
#   Cholesterol=0 | size=15, entropy=-0.000
#   Cholesterol=1 | size=15, entropy=-0.000
#   IG = 1.000
#   SplitInfo = 1.000, GainRatio = 1.000
#
# Feature: Na_to_K, Parent entropy = 1.000
#   Best split at 7.298, IG = 0.070
#   SplitInfo = 0.353, GainRatio = 0.198
# >>> Best feature = Cholesterol, threshold = None, score = 1.000
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 0.981
#   Best split at 50, IG = 0.981
#   SplitInfo = 0.981, GainRatio = 1.000
#
# Feature: Sex, Parent entropy = 0.981
#   Sex=1 | size=21, entropy=0.985
#   Sex=0 | size=10, entropy=0.971
#   IG = 0.001
#   SplitInfo = 0.907, GainRatio = 0.001
#
# Feature: Cholesterol, Parent entropy = 0.981
#   Cholesterol=0 | size=16, entropy=1.000
#   Cholesterol=1 | size=15, entropy=0.918
#   IG = 0.021
#   SplitInfo = 0.999, GainRatio = 0.021
#
# Feature: Na_to_K, Parent entropy = 0.981
#   Best split at 13.313, IG = 0.084
#   SplitInfo = 0.637, GainRatio = 0.132
# >>> Best feature = Age, threshold = 50, score = 1.000
# Fold 2 | Acc=0.97, Macro-F1=0.99, Micro-F1=0.97
#
# ==================================================
# Depth 0 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 1.882
#   Best split at 49, IG = 0.159
#   SplitInfo = 0.940, GainRatio = 0.170
#
# Feature: Sex, Parent entropy = 1.882
#   Sex=1 | size=83, entropy=1.989
#   Sex=0 | size=77, entropy=1.735
#   IG = 0.016
#   SplitInfo = 0.999, GainRatio = 0.016
#
# Feature: BP, Parent entropy = 1.882
#   BP=1 | size=49, entropy=1.519
#   BP=2 | size=53, entropy=0.956
#   BP=0 | size=58, entropy=1.405
#   IG = 0.591
#   SplitInfo = 1.582, GainRatio = 0.374
#
# Feature: Cholesterol, Parent entropy = 1.882
#   Cholesterol=0 | size=75, entropy=1.975
#   Cholesterol=1 | size=85, entropy=1.636
#   IG = 0.088
#   SplitInfo = 0.997, GainRatio = 0.088
#
# Feature: Na_to_K, Parent entropy = 1.882
#   Best split at 14.642, IG = 0.996
#   SplitInfo = 0.996, GainRatio = 1.000
# >>> Best feature = Na_to_K, threshold = 14.642, score = 1.000
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 1.649
#   Best split at 49, IG = 0.290
#   SplitInfo = 0.910, GainRatio = 0.319
#
# Feature: Sex, Parent entropy = 1.649
#   Sex=1 | size=46, entropy=1.799
#   Sex=0 | size=40, entropy=1.417
#   IG = 0.028
#   SplitInfo = 0.996, GainRatio = 0.028
#
# Feature: BP, Parent entropy = 1.649
#   BP=1 | size=26, entropy=0.983
#   BP=2 | size=33, entropy=-0.000
#   BP=0 | size=27, entropy=0.877
#   IG = 1.077
#   SplitInfo = 1.577, GainRatio = 0.683
#
# Feature: Cholesterol, Parent entropy = 1.649
#   Cholesterol=0 | size=40, entropy=1.833
#   Cholesterol=1 | size=46, entropy=1.184
#   IG = 0.163
#   SplitInfo = 0.996, GainRatio = 0.164
#
# Feature: Na_to_K, Parent entropy = 1.649
#   Best split at 8.607, IG = 0.060
#   SplitInfo = 0.668, GainRatio = 0.091
# >>> Best feature = BP, threshold = None, score = 0.683
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 0.983
#   Best split at 28, IG = 0.102
#   SplitInfo = 0.706, GainRatio = 0.145
#
# Feature: Sex, Parent entropy = 0.983
#   Sex=1 | size=14, entropy=1.000
#   Sex=0 | size=12, entropy=0.918
#   IG = 0.021
#   SplitInfo = 0.996, GainRatio = 0.021
#
# Feature: Cholesterol, Parent entropy = 0.983
#   Cholesterol=0 | size=11, entropy=-0.000
#   Cholesterol=1 | size=15, entropy=-0.000
#   IG = 0.983
#   SplitInfo = 0.983, GainRatio = 1.000
#
# Feature: Na_to_K, Parent entropy = 0.983
#   Best split at 7.298, IG = 0.102
#   SplitInfo = 0.391, GainRatio = 0.260
# >>> Best feature = Cholesterol, threshold = None, score = 1.000
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 0.877
#   Best split at 49, IG = 0.877
#   SplitInfo = 0.877, GainRatio = 1.000
#
# Feature: Sex, Parent entropy = 0.877
#   Sex=1 | size=17, entropy=0.937
#   Sex=0 | size=10, entropy=0.722
#   IG = 0.020
#   SplitInfo = 0.951, GainRatio = 0.021
#
# Feature: Cholesterol, Parent entropy = 0.877
#   Cholesterol=0 | size=12, entropy=0.918
#   Cholesterol=1 | size=15, entropy=0.837
#   IG = 0.004
#   SplitInfo = 0.991, GainRatio = 0.004
#
# Feature: Na_to_K, Parent entropy = 0.877
#   Best split at 13.313, IG = 0.054
#   SplitInfo = 0.503, GainRatio = 0.106
# >>> Best feature = Age, threshold = 49, score = 1.000
# Fold 3 | Acc=0.97, Macro-F1=0.96, Micro-F1=0.97
#
# ==================================================
# Depth 0 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 1.997
#   Best split at 50, IG = 0.216
#   SplitInfo = 0.978, GainRatio = 0.221
#
# Feature: Sex, Parent entropy = 1.997
#   Sex=0 | size=81, entropy=1.859
#   Sex=1 | size=79, entropy=2.106
#   IG = 0.016
#   SplitInfo = 1.000, GainRatio = 0.016
#
# Feature: BP, Parent entropy = 1.997
#   BP=0 | size=63, entropy=1.534
#   BP=1 | size=51, entropy=1.507
#   BP=2 | size=46, entropy=0.950
#   IG = 0.639
#   SplitInfo = 1.572, GainRatio = 0.406
#
# Feature: Cholesterol, Parent entropy = 1.997
#   Cholesterol=0 | size=87, entropy=2.035
#   Cholesterol=1 | size=73, entropy=1.776
#   IG = 0.080
#   SplitInfo = 0.994, GainRatio = 0.080
#
# Feature: Na_to_K, Parent entropy = 1.997
#   Best split at 14.642, IG = 0.991
#   SplitInfo = 0.991, GainRatio = 1.000
# >>> Best feature = Na_to_K, threshold = 14.642, score = 1.000
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 1.808
#   Best split at 50, IG = 0.388
#   SplitInfo = 0.979, GainRatio = 0.396
#
# Feature: Sex, Parent entropy = 1.808
#   Sex=1 | size=47, entropy=1.903
#   Sex=0 | size=42, entropy=1.659
#   IG = 0.021
#   SplitInfo = 0.998, GainRatio = 0.021
#
# Feature: BP, Parent entropy = 1.808
#   BP=1 | size=26, entropy=0.996
#   BP=2 | size=29, entropy=-0.000
#   BP=0 | size=34, entropy=0.998
#   IG = 1.136
#   SplitInfo = 1.576, GainRatio = 0.721
#
# Feature: Cholesterol, Parent entropy = 1.808
#   Cholesterol=0 | size=47, entropy=1.925
#   Cholesterol=1 | size=42, entropy=1.377
#   IG = 0.142
#   SplitInfo = 0.998, GainRatio = 0.142
#
# Feature: Na_to_K, Parent entropy = 1.808
#   Best split at 13.091, IG = 0.072
#   SplitInfo = 0.571, GainRatio = 0.126
# >>> Best feature = BP, threshold = None, score = 0.721
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 0.996
#   Best split at 26, IG = 0.083
#   SplitInfo = 0.706, GainRatio = 0.117
#
# Feature: Sex, Parent entropy = 0.996
#   Sex=1 | size=14, entropy=1.000
#   Sex=0 | size=12, entropy=0.980
#   IG = 0.005
#   SplitInfo = 0.996, GainRatio = 0.005
#
# Feature: Cholesterol, Parent entropy = 0.996
#   Cholesterol=0 | size=12, entropy=-0.000
#   Cholesterol=1 | size=14, entropy=-0.000
#   IG = 0.996
#   SplitInfo = 0.996, GainRatio = 1.000
#
# Feature: Na_to_K, Parent entropy = 0.996
#   Best split at 10.444, IG = 0.105
#   SplitInfo = 0.961, GainRatio = 0.110
# >>> Best feature = Cholesterol, threshold = None, score = 1.000
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 0.998
#   Best split at 50, IG = 0.998
#   SplitInfo = 0.998, GainRatio = 1.000
#
# Feature: Sex, Parent entropy = 0.998
#   Sex=1 | size=21, entropy=0.998
#   Sex=0 | size=13, entropy=0.996
#   IG = 0.000
#   SplitInfo = 0.960, GainRatio = 0.000
#
# Feature: Cholesterol, Parent entropy = 0.998
#   Cholesterol=0 | size=17, entropy=0.998
#   Cholesterol=1 | size=17, entropy=0.998
#   IG = 0.000
#   SplitInfo = 1.000, GainRatio = 0.000
#
# Feature: Na_to_K, Parent entropy = 0.998
#   Best split at 13.091, IG = 0.181
#   SplitInfo = 0.602, GainRatio = 0.300
# >>> Best feature = Age, threshold = 50, score = 1.000
# Fold 4 | Acc=1.00, Macro-F1=1.00, Micro-F1=1.00
#
# ==================================================
# Depth 0 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 1.935
#   Best split at 50, IG = 0.191
#   SplitInfo = 0.934, GainRatio = 0.205
#
# Feature: Sex, Parent entropy = 1.935
#   Sex=0 | size=82, entropy=1.864
#   Sex=1 | size=78, entropy=1.999
#   IG = 0.005
#   SplitInfo = 1.000, GainRatio = 0.005
#
# Feature: BP, Parent entropy = 1.935
#   BP=0 | size=60, entropy=1.472
#   BP=1 | size=52, entropy=1.532
#   BP=2 | size=48, entropy=0.989
#   IG = 0.588
#   SplitInfo = 1.579, GainRatio = 0.373
#
# Feature: Cholesterol, Parent entropy = 1.935
#   Cholesterol=0 | size=83, entropy=2.008
#   Cholesterol=1 | size=77, entropy=1.640
#   IG = 0.104
#   SplitInfo = 0.999, GainRatio = 0.104
#
# Feature: Na_to_K, Parent entropy = 1.935
#   Best split at 14.642, IG = 0.998
#   SplitInfo = 0.998, GainRatio = 1.000
# >>> Best feature = Na_to_K, threshold = 14.642, score = 1.000
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 1.784
#   Best split at 50, IG = 0.364
#   SplitInfo = 0.930, GainRatio = 0.391
#
# Feature: Sex, Parent entropy = 1.784
#   Sex=1 | size=43, entropy=1.826
#   Sex=0 | size=41, entropy=1.729
#   IG = 0.006
#   SplitInfo = 1.000, GainRatio = 0.006
#
# Feature: BP, Parent entropy = 1.784
#   BP=1 | size=28, entropy=0.996
#   BP=2 | size=27, entropy=-0.000
#   BP=0 | size=29, entropy=0.978
#   IG = 1.114
#   SplitInfo = 1.584, GainRatio = 0.703
#
# Feature: Cholesterol, Parent entropy = 1.784
#   Cholesterol=0 | size=44, entropy=1.906
#   Cholesterol=1 | size=40, entropy=1.233
#   IG = 0.199
#   SplitInfo = 0.998, GainRatio = 0.199
#
# Feature: Na_to_K, Parent entropy = 1.784
#   Best split at 9.664, IG = 0.079
#   SplitInfo = 0.811, GainRatio = 0.098
# >>> Best feature = BP, threshold = None, score = 0.703
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 0.996
#   Best split at 59, IG = 0.143
#   SplitInfo = 0.592, GainRatio = 0.242
#
# Feature: Sex, Parent entropy = 0.996
#   Sex=1 | size=16, entropy=0.989
#   Sex=0 | size=12, entropy=1.000
#   IG = 0.003
#   SplitInfo = 0.985, GainRatio = 0.003
#
# Feature: Cholesterol, Parent entropy = 0.996
#   Cholesterol=0 | size=13, entropy=-0.000
#   Cholesterol=1 | size=15, entropy=-0.000
#   IG = 0.996
#   SplitInfo = 0.996, GainRatio = 1.000
#
# Feature: Na_to_K, Parent entropy = 0.996
#   Best split at 8.151, IG = 0.084
#   SplitInfo = 0.371, GainRatio = 0.225
# >>> Best feature = Cholesterol, threshold = None, score = 1.000
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 0.978
#   Best split at 50, IG = 0.978
#   SplitInfo = 0.978, GainRatio = 1.000
#
# Feature: Sex, Parent entropy = 0.978
#   Sex=1 | size=16, entropy=0.954
#   Sex=0 | size=13, entropy=0.996
#   IG = 0.006
#   SplitInfo = 0.992, GainRatio = 0.006
#
# Feature: Cholesterol, Parent entropy = 0.978
#   Cholesterol=0 | size=16, entropy=0.896
#   Cholesterol=1 | size=13, entropy=0.996
#   IG = 0.038
#   SplitInfo = 0.992, GainRatio = 0.038
#
# Feature: Na_to_K, Parent entropy = 0.978
#   Best split at 9.664, IG = 0.151
#   SplitInfo = 0.663, GainRatio = 0.227
# >>> Best feature = Age, threshold = 50, score = 1.000
# Fold 5 | Acc=1.00, Macro-F1=1.00, Micro-F1=1.00
#
# === Final Results ( C4.5 ) ===
# Avg Acc = 0.99
# Avg Macro-F1 = 0.9890524014483842
# Avg Micro-F1 = 0.99

# %%
def print_tree(tree,indent=""):
    if tree["leaf"]:
        print(indent,"→",tree["label"])
    else:
        f,th = tree["feature"], tree["threshold"]
        if th is None:
            for v,ch in tree["children"].items():
                print(indent,f,"=",v)
                print_tree(ch,indent+"   ")
        else:
            print(indent,f,"<=",th)
            print_tree(tree["children"]["<="],indent+"   ")
            print(indent,f,">",th)
            print_tree(tree["children"][">"],indent+"   ")

print("\nFinal ID3 Tree (full data):")
id3_tree = build_tree(df_drug.drop(columns=["Drug"]), df_drug["Drug"], "ID3")
print_tree(id3_tree)

print("\nFinal C4.5 Tree (full data):")
c45_tree = build_tree(df_drug.drop(columns=["Drug"]), df_drug["Drug"], "C4.5")
print_tree(c45_tree)
# Out:
# Final ID3 Tree (full data):
#
# ==================================================
# Depth 0 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 1.969
#   Best split at 50, IG = 0.195
#
# Feature: Sex, Parent entropy = 1.969
#   Sex=0 | size=96, entropy=1.865
#   Sex=1 | size=104, entropy=2.050
#   IG = 0.008
#
# Feature: BP, Parent entropy = 1.969
#   BP=0 | size=77, entropy=1.495
#   BP=1 | size=64, entropy=1.527
#   BP=2 | size=59, entropy=0.965
#   IG = 0.620
#
# Feature: Cholesterol, Parent entropy = 1.969
#   Cholesterol=0 | size=103, entropy=2.041
#   Cholesterol=1 | size=97, entropy=1.701
#   IG = 0.093
#
# Feature: Na_to_K, Parent entropy = 1.969
#   Best split at 14.642, IG = 0.994
# >>> Best feature = Na_to_K, threshold = 14.642, score = 0.994
#
# ==================================================
# Depth 1 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 1.788
#   Best split at 50, IG = 0.358
#
# Feature: Sex, Parent entropy = 1.788
#   Sex=1 | size=60, entropy=1.850
#   Sex=0 | size=49, entropy=1.695
#   IG = 0.008
#
# Feature: BP, Parent entropy = 1.788
#   BP=1 | size=34, entropy=0.998
#   BP=2 | size=36, entropy=-0.000
#   BP=0 | size=39, entropy=0.977
#   IG = 1.128
#
# Feature: Cholesterol, Parent entropy = 1.788
#   Cholesterol=0 | size=56, entropy=1.924
#   Cholesterol=1 | size=53, entropy=1.293
#   IG = 0.171
#
# Feature: Na_to_K, Parent entropy = 1.788
#   Best split at 9.443, IG = 0.052
# >>> Best feature = BP, threshold = None, score = 1.128
#
# ==================================================
# Depth 2 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 0.998
#   Best split at 28, IG = 0.087
#
# Feature: Sex, Parent entropy = 0.998
#   Sex=1 | size=19, entropy=0.998
#   Sex=0 | size=15, entropy=0.997
#   IG = 0.000
#
# Feature: Cholesterol, Parent entropy = 0.998
#   Cholesterol=0 | size=16, entropy=-0.000
#   Cholesterol=1 | size=18, entropy=-0.000
#   IG = 0.998
#
# Feature: Na_to_K, Parent entropy = 0.998
#   Best split at 7.298, IG = 0.067
# >>> Best feature = Cholesterol, threshold = None, score = 0.998
#
# ==================================================
# Depth 2 | Algorithm = ID3
#
# Feature: Age, Parent entropy = 0.977
#   Best split at 50, IG = 0.977
#
# Feature: Sex, Parent entropy = 0.977
#   Sex=1 | size=24, entropy=0.980
#   Sex=0 | size=15, entropy=0.971
#   IG = 0.000
#
# Feature: Cholesterol, Parent entropy = 0.977
#   Cholesterol=0 | size=20, entropy=0.971
#   Cholesterol=1 | size=19, entropy=0.982
#   IG = 0.000
#
# Feature: Na_to_K, Parent entropy = 0.977
#   Best split at 13.313, IG = 0.067
# >>> Best feature = Age, threshold = 50, score = 0.977
#  Na_to_K <= 14.642
#     BP = 1
#        Cholesterol = 0
#           → 2
#        Cholesterol = 1
#           → 3
#     BP = 2
#        → 3
#     BP = 0
#        Age <= 50
#           → 0
#        Age > 50
#           → 1
#  Na_to_K > 14.642
#     → 4
#
# Final C4.5 Tree (full data):
#
# ==================================================
# Depth 0 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 1.969
#   Best split at 50, IG = 0.195
#   SplitInfo = 0.947, GainRatio = 0.206
#
# Feature: Sex, Parent entropy = 1.969
#   Sex=0 | size=96, entropy=1.865
#   Sex=1 | size=104, entropy=2.050
#   IG = 0.008
#   SplitInfo = 0.999, GainRatio = 0.008
#
# Feature: BP, Parent entropy = 1.969
#   BP=0 | size=77, entropy=1.495
#   BP=1 | size=64, entropy=1.527
#   BP=2 | size=59, entropy=0.965
#   IG = 0.620
#   SplitInfo = 1.576, GainRatio = 0.394
#
# Feature: Cholesterol, Parent entropy = 1.969
#   Cholesterol=0 | size=103, entropy=2.041
#   Cholesterol=1 | size=97, entropy=1.701
#   IG = 0.093
#   SplitInfo = 0.999, GainRatio = 0.093
#
# Feature: Na_to_K, Parent entropy = 1.969
#   Best split at 14.642, IG = 0.994
#   SplitInfo = 0.994, GainRatio = 1.000
# >>> Best feature = Na_to_K, threshold = 14.642, score = 1.000
#
# ==================================================
# Depth 1 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 1.788
#   Best split at 50, IG = 0.358
#   SplitInfo = 0.941, GainRatio = 0.381
#
# Feature: Sex, Parent entropy = 1.788
#   Sex=1 | size=60, entropy=1.850
#   Sex=0 | size=49, entropy=1.695
#   IG = 0.008
#   SplitInfo = 0.993, GainRatio = 0.008
#
# Feature: BP, Parent entropy = 1.788
#   BP=1 | size=34, entropy=0.998
#   BP=2 | size=36, entropy=-0.000
#   BP=0 | size=39, entropy=0.977
#   IG = 1.128
#   SplitInfo = 1.583, GainRatio = 0.713
#
# Feature: Cholesterol, Parent entropy = 1.788
#   Cholesterol=0 | size=56, entropy=1.924
#   Cholesterol=1 | size=53, entropy=1.293
#   IG = 0.171
#   SplitInfo = 0.999, GainRatio = 0.171
#
# Feature: Na_to_K, Parent entropy = 1.788
#   Best split at 9.443, IG = 0.052
#   SplitInfo = 0.808, GainRatio = 0.064
# >>> Best feature = BP, threshold = None, score = 0.713
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 0.998
#   Best split at 28, IG = 0.087
#   SplitInfo = 0.672, GainRatio = 0.129
#
# Feature: Sex, Parent entropy = 0.998
#   Sex=1 | size=19, entropy=0.998
#   Sex=0 | size=15, entropy=0.997
#   IG = 0.000
#   SplitInfo = 0.990, GainRatio = 0.000
#
# Feature: Cholesterol, Parent entropy = 0.998
#   Cholesterol=0 | size=16, entropy=-0.000
#   Cholesterol=1 | size=18, entropy=-0.000
#   IG = 0.998
#   SplitInfo = 0.998, GainRatio = 1.000
#
# Feature: Na_to_K, Parent entropy = 0.998
#   Best split at 7.298, IG = 0.067
#   SplitInfo = 0.323, GainRatio = 0.207
# >>> Best feature = Cholesterol, threshold = None, score = 1.000
#
# ==================================================
# Depth 2 | Algorithm = C4.5
#
# Feature: Age, Parent entropy = 0.977
#   Best split at 50, IG = 0.977
#   SplitInfo = 0.977, GainRatio = 1.000
#
# Feature: Sex, Parent entropy = 0.977
#   Sex=1 | size=24, entropy=0.980
#   Sex=0 | size=15, entropy=0.971
#   IG = 0.000
#   SplitInfo = 0.961, GainRatio = 0.000
#
# Feature: Cholesterol, Parent entropy = 0.977
#   Cholesterol=0 | size=20, entropy=0.971
#   Cholesterol=1 | size=19, entropy=0.982
#   IG = 0.000
#   SplitInfo = 1.000, GainRatio = 0.000
#
# Feature: Na_to_K, Parent entropy = 0.977
#   Best split at 13.313, IG = 0.067
#   SplitInfo = 0.552, GainRatio = 0.122
# >>> Best feature = Age, threshold = 50, score = 1.000
#  Na_to_K <= 14.642
#     BP = 1
#        Cholesterol = 0
#           → 2
#        Cholesterol = 1
#           → 3
#     BP = 2
#        → 3
#     BP = 0
#        Age <= 50
#           → 0
#        Age > 50
#           → 1
#  Na_to_K > 14.642
#     → 4
